# %% [markdown]
# # Visualize  your RAG Data - EDA for Retrieval-Augmented Generation
# ## How to use UMAP dimensionality reduction for Embeddings to show  Questions, Answers and their relationships to source documents with OpenAI, Langchain and ChromaDB
# This notebook is part of an [article at ITNEXT.](https://itnext.io/visualize-your-rag-data-eda-for-retrieval-augmented-generation-0701ee98768f)

# %% [markdown]
# ### Get ready

# %%
# !pip install langchain chromadb renumics-spotlight sentence-transformers einops
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.1.20)
# Requirement already satisfied: chromadb in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: renumics-spotlight in /usr/local/lib/python3.10/dist-packages (1.6.8)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (2.7.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.6.6)
# Requirement already satisfied: langchain-community<0.1,>=0.0.38 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.52 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.57)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.24.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.3.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.111.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.29.0)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.17.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (5.7.1)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.63.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb) (3.10.3)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (23.2.1)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.4.4)
# Requirement already satisfied: av in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (12.0.0)
# Requirement already satisfied: cleanlab in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.6.4)
# Requirement already satisfied: cleanvision in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.3.6)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (8.1.7)
# Requirement already satisfied: databases[sqlite]>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.9.0)
# Requirement already satisfied: datasets[audio]<3.0.0,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.19.1)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (5.6.3)
# Requirement already satisfied: filetype in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.2.0)
# Requirement already satisfied: h5py>3.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.9.0)
# Requirement already satisfied: httptools in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.6.1)
# Requirement already satisfied: httpx<0.24.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.23.3)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2024.1.1)
# Requirement already satisfied: imageio>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.31.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (7.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.1.4)
# Requirement already satisfied: loguru in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.7.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.3)
# Requirement already satisfied: numba<0.58.0,>=0.57.1 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.57.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (23.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.0.3)
# Requirement already satisfied: pillow<11.0.0,>=10.0.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (10.0.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (3.10.0)
# Requirement already satisfied: py-machineid in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.5.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (14.0.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (2.2.1)
# Requirement already satisfied: pygltflib>=1.15.1 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.16.2)
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.9)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.19.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (1.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (67.7.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.10.2)
# Requirement already satisfied: transformers<5.0.0,>=4.35.2 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.40.2)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (4.3.2)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.5.6)
# Requirement already satisfied: uvloop>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.19.0)
# Requirement already satisfied: validators in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (0.28.1)
# Requirement already satisfied: websockets in /usr/local/lib/python3.10/dist-packages (from renumics-spotlight) (12.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.2.1+cu121)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.10/dist-packages (from databases[sqlite]>=0.1.3->renumics-spotlight) (0.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (3.14.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (2023.6.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.12.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.10.2)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.0.3)
# Requirement already satisfied: python-multipart>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (5.9.0)
# Requirement already satisfied: email_validator>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (2.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.24.0,>=0.23.0->renumics-spotlight) (2024.2.2)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from httpx<0.24.0,>=0.23.0->renumics-spotlight) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx<0.24.0,>=0.23.0->renumics-spotlight) (1.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.24.0,>=0.23.0->renumics-spotlight) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->renumics-spotlight) (2.1.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.52->langchain) (1.33)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba<0.58.0,>=0.57.1->renumics-spotlight) (0.40.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.45b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.0.3->renumics-spotlight) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.35.2->renumics-spotlight) (2023.12.25)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.35.2->renumics-spotlight) (0.4.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: termcolor>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from cleanlab->renumics-spotlight) (2.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->renumics-spotlight) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->renumics-spotlight) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->renumics-spotlight) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->renumics-spotlight) (3.5.0)
# Requirement already satisfied: tabulate>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from cleanvision->renumics-spotlight) (0.9.0)
# Requirement already satisfied: imagehash>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from cleanvision->renumics-spotlight) (4.3.1)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.10/dist-packages (from cleanvision->renumics-spotlight) (3.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->renumics-spotlight) (3.0.10)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->renumics-spotlight) (0.2.13)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa->renumics-spotlight) (0.6.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->renumics-spotlight) (2024.5.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->renumics-spotlight) (1.6.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn->renumics-spotlight) (0.5.12)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->renumics-spotlight) (3.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.18.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->renumics-spotlight) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->renumics-spotlight) (6.3.3)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->renumics-spotlight) (4.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain) (2.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.4->cleanvision->renumics-spotlight) (3.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (6.5.5)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (3.0.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (1.0.8)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->renumics-spotlight) (1.2.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->renumics-spotlight) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa->datasets[audio]<3.0.0,>=2.12.0->renumics-spotlight) (4.2.1)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (4.19.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.18.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->renumics-spotlight) (0.5.1)

# %% [markdown]
# ### Prepare documents

# %%
from langchain.vectorstores.chroma import Chroma
from langchain.embeddings import HuggingFaceEmbeddings
import pandas as pd
import numpy as np

# %%
# create embeddings model
model_kwargs = {'trust_remote_code': True}
embedding = HuggingFaceEmbeddings(model_name='nomic-ai/nomic-embed-text-v1.5', model_kwargs=model_kwargs)
# Out:
# modules.json:   0%|          | 0.00/255 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/140 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/69.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# configuration_hf_nomic_bert.py:   0%|          | 0.00/1.96k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nomic-ai/nomic-bert-2048:
# - configuration_hf_nomic_bert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_hf_nomic_bert.py:   0%|          | 0.00/52.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/nomic-ai/nomic-bert-2048:
# - modeling_hf_nomic_bert.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/547M [00:00<?, ?B/s]
# WARNING:transformers_modules.nomic-ai.nomic-bert-2048.7b260c5676ce4ba4a117f15bc24ac13ab4b81695.modeling_hf_nomic_bert:<All keys matched successfully>
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/286 [00:00<?, ?B/s]

# %%
# Retrieve vector store
vectordb = Chroma(persist_directory='db_v3', embedding_function=embedding)

# %% [markdown]
# ### Ask a Question

# %%
# Taken from app
sample_questions = [
    'How to enroll?',
    'How do I apply for a car sticker?',
    'Who to contact about student organizations?',
    'What is the difference between BS CS and BS IT?',
    'What is the difference between overload, tutorial, and override?',
    'What are the fee discounts available and how can I apply for them?',
    'Please discuss the core values of USC.'
]
question = sample_questions[0]

# %%
retriever = vectordb.as_retriever(search_kwargs={"k": 5})
docs = retriever.get_relevant_documents(question)
sources = [doc.metadata.get("source") for doc in docs]
sources
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# ['A18-Enrollment Steps for Continuing Students.txt',
#  'A15-Post-Admission Enrollment Steps.txt',
#  'A16-Enrollment Mechanics.txt',
#  'A24-Simultaneous Enrollment.txt',
#  'A28-Additional Enrollment Steps (Shiftee).txt']

# %% [markdown]
# ### Visualize

# %%
# extract embeddings for the documents from the vector store and store them in a dataframe
response = vectordb.get(include=["metadatas", "documents", "embeddings"])
df = pd.DataFrame(
    {
        "id": response["ids"],
        "source": [metadata.get("source") for metadata in response["metadatas"]],
        "document": response["documents"],
        "embedding": response["embeddings"],
    }
)

# %%
df = df.sort_values(by=['source'])
df
# Out:
#                                        id  \
# 95   ae0dbca3-cc02-44e9-b21d-bb4110f0ffb8
# 119  da84031c-f3f3-4e2c-aca9-e9f3068247c7
# 90   a68a39f3-0e0a-44e4-97eb-c2da93483cc8
# 15   18f81ef3-6772-44a3-a32c-7d6874f0f137
# 37   452a0946-0f7a-4cdc-9dae-973aa0c3adec
# ..                                    ...
# 107  c2089b3d-e87b-47b0-b7b1-4095ae6bc15b
# 32   40a5a9f2-383b-4473-9bad-15cd2544b6d5
# 52   65758b26-9d29-4924-8ddc-55ad9e86bb97
# 103  bc2b6782-1a0e-4c6e-b3e5-c6b5c624ae0e
# 97   b275d381-221f-464b-a7c6-ed4453f15336
#
#                                                 source  \
# 95                               A00-Abbreviations.txt
# 119                                A01-Description.txt
# 90   A02-Catholic Identity, Vision Mission and Core...
# 15                         A03-The University Seal.txt
# 37                                     A04-History.txt
# ..                                                 ...
# 107                                B38-BS Pharmacy.txt
# 32                               B39-BS Psychology.txt
# 52                       B40-BS Tourism Management.txt
# 103     B41-B Secondary Education Major in Science.txt
# 97   B42-B Special Needs Education with specializat...
#
#                                               document  \
# 95   USC stands for University of San Carlos.\nSVD ...
# 119  TOPIC 1: Description\n\nUniversity of San Carl...
# 90   TOPIC 2: Catholic Identity, Vision, Mission, a...
# 15   Topic 3: The University Seal\n\nThe University...
# 37   Topic 4: History\n\nThe University of San Carl...
# ..                                                 ...
# 107  Bachelor of Science in Pharmacy / BS Pharmacy ...
# 32   Bachelor of Science in Psychology / BS Psychol...
# 52   Bachelor of Science in Tourism Management / BS...
# 103  Bachelor of Secondary Education Major in Scien...
# 97   Bachelor of Special Needs Education with speci...
#
#                                              embedding
# 95   [0.46299073100090027, 0.36808809638023376, -2....
# 119  [-0.01337280310690403, 1.720857858657837, -3.1...
# 90   [0.48381316661834717, 0.8756269812583923, -3.3...
# 15   [-0.26976484060287476, 1.9007909297943115, -3....
# 37   [0.26369062066078186, 1.508581280708313, -3.29...
# ..                                                 ...
# 107  [-0.570658802986145, 0.36090323328971863, -2.2...
# 32   [-0.12269929051399231, 0.17832259833812714, -2...
# 52   [-1.1161071062088013, 1.0692917108535767, -3.6...
# 103  [-0.15809260308742523, 0.5261877179145813, -2....
# 97   [-0.3580893576145172, 1.1250261068344116, -3.1...
#
# [130 rows x 4 columns]

# %%
# add the question with their embeddings to the dataframe
count = 0
question_rows = []
for question in sample_questions:
  count += 1
  question_rows.append(
      {
          "id": f"question_{count}",
          "question": question,
          "embedding": embedding.embed_query(question),
      }
  )
question_rows = pd.DataFrame(question_rows)
df = pd.concat([question_rows, df])
df.head(20)
# Out:
#                                        id  \
# 0                              question_1
# 1                              question_2
# 2                              question_3
# 3                              question_4
# 4                              question_5
# 5                              question_6
# 6                              question_7
# 95   ae0dbca3-cc02-44e9-b21d-bb4110f0ffb8
# 119  da84031c-f3f3-4e2c-aca9-e9f3068247c7
# 90   a68a39f3-0e0a-44e4-97eb-c2da93483cc8
# 15   18f81ef3-6772-44a3-a32c-7d6874f0f137
# 37   452a0946-0f7a-4cdc-9dae-973aa0c3adec
# 108  c7242ac4-eb9a-4ca9-a553-0be16a1341e7
# 83   9c8ed973-ff53-4a8a-ba6e-6a0657141117
# 89   a673ffee-3754-4395-83b0-fb37ba8b70b8
# 101  b9622134-99f3-4761-b4e7-a246f5094994
# 44   5286140a-903e-4923-839d-846cb3b5065c
# 19   1df03f15-bcd2-4118-9251-26577e15b54e
# 1    04f29dd9-dc6d-4afa-888a-359be093d380
# 77   914de2cf-a197-40dc-8af8-26308dfc8432
#
#                                               question  \
# 0                                       How to enroll?
# 1                    How do I apply for a car sticker?
# 2          Who to contact about student organizations?
# 3      What is the difference between BS CS and BS IT?
# 4    What is the difference between overload, tutor...
# 5    What are the fee discounts available and how c...
# 6               Please discuss the core values of USC.
# 95                                                 NaN
# 119                                                NaN
# 90                                                 NaN
# 15                                                 NaN
# 37                                                 NaN
# 108                                                NaN
# 83                                                 NaN
# 89                                                 NaN
# 101                                                NaN
# 44                                                 NaN
# 19                                                 NaN
# 1                                                  NaN
# 77                                                 NaN
#
#                                              embedding  \
# 0    [-1.4416790008544922, 1.325736403465271, -3.31...
# 1    [-0.09891726821660995, -0.4405957758426666, -3...
# 2    [-1.1395211219787598, -0.04957957565784454, -3...
# 3    [1.1334507465362549, 1.0081663131713867, -2.41...
# 4    [1.0645222663879395, 0.7283675670623779, -3.81...
# 5    [-0.5865501761436462, 0.9015997648239136, -3.5...
# 6    [0.12190892547369003, 0.8585222363471985, -3.4...
# 95   [0.46299073100090027, 0.36808809638023376, -2....
# 119  [-0.01337280310690403, 1.720857858657837, -3.1...
# 90   [0.48381316661834717, 0.8756269812583923, -3.3...
# 15   [-0.26976484060287476, 1.9007909297943115, -3....
# 37   [0.26369062066078186, 1.508581280708313, -3.29...
# 108  [0.10985635221004486, 0.9737294912338257, -2.8...
# 83   [-0.2297847419977188, 1.527048110961914, -3.37...
# 89   [0.21950210630893707, -0.1793101727962494, -4....
# 101  [-0.3399277627468109, 1.633723258972168, -3.11...
# 44   [-0.2553839683532715, 1.5201339721679688, -2.6...
# 19   [-0.6737183332443237, 0.039311494678258896, -2...
# 1    [-0.15944167971611023, 0.8384157419204712, -2....
# 77   [-0.6744738817214966, 0.4461701810359955, -2.9...
#
#                                                 source  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 95                               A00-Abbreviations.txt
# 119                                A01-Description.txt
# 90   A02-Catholic Identity, Vision Mission and Core...
# 15                         A03-The University Seal.txt
# 37                                     A04-History.txt
# 108                                    A04-History.txt
# 83                           A05-University Saints.txt
# 89                           A05-University Saints.txt
# 101               A06-USC Organizational Structure.txt
# 44                                   A07-Admission.txt
# 19                A08-Admission Steps for Freshmen.txt
# 1    A09-Admission Steps for International Students...
# 77              A10-Admission Steps for Transferee.txt
#
#                                               document
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 95   USC stands for University of San Carlos.\nSVD ...
# 119  TOPIC 1: Description\n\nUniversity of San Carl...
# 90   TOPIC 2: Catholic Identity, Vision, Mission, a...
# 15   Topic 3: The University Seal\n\nThe University...
# 37   Topic 4: History\n\nThe University of San Carl...
# 108  In 1957, the University became one of the 11 (...
# 83   Topic 5: University Saints\n\nThe three univer...
# 89   ST. JOSEPH FREINADEMETZ (1852-1908) \n\nSt. Jo...
# 101  Topic 6: USC Organizational Structure\n\nThe U...
# 44   Topic 7: Admission\n\nThe academic admission r...
# 19   Topic 8: Admission Steps for Freshmen\n\nThe i...
# 1    Topic 9: Admission Steps for International Stu...
# 77   Topic 10: Admission Steps for Transferee\n\nTh...

# %%
# make 2 copies of df: df_euclid, df_cosine
# note: df_euclid will use euclidean distance, df_cosine will use cosine similarity
df_euclid = df.copy(deep=True)
df_cosine = df.copy(deep=True)

# %%
# calculate the distance between the question and the document embeddings
# Euclid
count = 0
for question in sample_questions:
  count += 1
  question_embedding = embedding.embed_query(question)
  df_euclid[f"dist_{count}"] = df.apply(
      # Euclidean distance - norm(A - B)
      lambda row: np.linalg.norm(np.array(row["embedding"]) - question_embedding),
      axis=1,
  )
  df_cosine[f"dist_{count}"] = df.apply(
      # Cosine similarity - dot(A,B)/(norm(A, axis=1)*norm(B))
      lambda row: np.dot(np.array(row["embedding"]),question_embedding)/(np.linalg.norm(np.array(row["embedding"]))*np.linalg.norm(question_embedding)),
      axis=1,
  )

# %%
df_euclid.head(20)
# Out:
#                                        id  \
# 0                              question_1
# 1                              question_2
# 2                              question_3
# 3                              question_4
# 4                              question_5
# 5                              question_6
# 6                              question_7
# 95   ae0dbca3-cc02-44e9-b21d-bb4110f0ffb8
# 119  da84031c-f3f3-4e2c-aca9-e9f3068247c7
# 90   a68a39f3-0e0a-44e4-97eb-c2da93483cc8
# 15   18f81ef3-6772-44a3-a32c-7d6874f0f137
# 37   452a0946-0f7a-4cdc-9dae-973aa0c3adec
# 108  c7242ac4-eb9a-4ca9-a553-0be16a1341e7
# 83   9c8ed973-ff53-4a8a-ba6e-6a0657141117
# 89   a673ffee-3754-4395-83b0-fb37ba8b70b8
# 101  b9622134-99f3-4761-b4e7-a246f5094994
# 44   5286140a-903e-4923-839d-846cb3b5065c
# 19   1df03f15-bcd2-4118-9251-26577e15b54e
# 1    04f29dd9-dc6d-4afa-888a-359be093d380
# 77   914de2cf-a197-40dc-8af8-26308dfc8432
#
#                                               question  \
# 0                                       How to enroll?
# 1                    How do I apply for a car sticker?
# 2          Who to contact about student organizations?
# 3      What is the difference between BS CS and BS IT?
# 4    What is the difference between overload, tutor...
# 5    What are the fee discounts available and how c...
# 6               Please discuss the core values of USC.
# 95                                                 NaN
# 119                                                NaN
# 90                                                 NaN
# 15                                                 NaN
# 37                                                 NaN
# 108                                                NaN
# 83                                                 NaN
# 89                                                 NaN
# 101                                                NaN
# 44                                                 NaN
# 19                                                 NaN
# 1                                                  NaN
# 77                                                 NaN
#
#                                              embedding  \
# 0    [-1.4416790008544922, 1.325736403465271, -3.31...
# 1    [-0.09891726821660995, -0.4405957758426666, -3...
# 2    [-1.1395211219787598, -0.04957957565784454, -3...
# 3    [1.1334507465362549, 1.0081663131713867, -2.41...
# 4    [1.0645222663879395, 0.7283675670623779, -3.81...
# 5    [-0.5865501761436462, 0.9015997648239136, -3.5...
# 6    [0.12190892547369003, 0.8585222363471985, -3.4...
# 95   [0.46299073100090027, 0.36808809638023376, -2....
# 119  [-0.01337280310690403, 1.720857858657837, -3.1...
# 90   [0.48381316661834717, 0.8756269812583923, -3.3...
# 15   [-0.26976484060287476, 1.9007909297943115, -3....
# 37   [0.26369062066078186, 1.508581280708313, -3.29...
# 108  [0.10985635221004486, 0.9737294912338257, -2.8...
# 83   [-0.2297847419977188, 1.527048110961914, -3.37...
# 89   [0.21950210630893707, -0.1793101727962494, -4....
# 101  [-0.3399277627468109, 1.633723258972168, -3.11...
# 44   [-0.2553839683532715, 1.5201339721679688, -2.6...
# 19   [-0.6737183332443237, 0.039311494678258896, -2...
# 1    [-0.15944167971611023, 0.8384157419204712, -2....
# 77   [-0.6744738817214966, 0.4461701810359955, -2.9...
#
#                                                 source  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 95                               A00-Abbreviations.txt
# 119                                A01-Description.txt
# 90   A02-Catholic Identity, Vision Mission and Core...
# 15                         A03-The University Seal.txt
# 37                                     A04-History.txt
# 108                                    A04-History.txt
# 83                           A05-University Saints.txt
# 89                           A05-University Saints.txt
# 101               A06-USC Organizational Structure.txt
# 44                                   A07-Admission.txt
# 19                A08-Admission Steps for Freshmen.txt
# 1    A09-Admission Steps for International Students...
# 77              A10-Admission Steps for Transferee.txt
#
#                                               document     dist_1     dist_2  \
# 0                                                  NaN   0.000000  21.620063
# 1                                                  NaN  21.620063   0.000000
# 2                                                  NaN  22.668039  23.503184
# 3                                                  NaN  25.112623  25.036329
# 4                                                  NaN  23.288184  23.969033
# 5                                                  NaN  22.087395  19.371689
# 6                                                  NaN  25.292707  24.768926
# 95   USC stands for University of San Carlos.\nSVD ...  21.597172  20.620203
# 119  TOPIC 1: Description\n\nUniversity of San Carl...  22.745493  23.098682
# 90   TOPIC 2: Catholic Identity, Vision, Mission, a...  23.475701  22.903508
# 15   Topic 3: The University Seal\n\nThe University...  23.388530  22.535205
# 37   Topic 4: History\n\nThe University of San Carl...  22.824310  23.482220
# 108  In 1957, the University became one of the 11 (...  21.645491  21.953377
# 83   Topic 5: University Saints\n\nThe three univer...  23.463480  23.705956
# 89   ST. JOSEPH FREINADEMETZ (1852-1908) \n\nSt. Jo...  23.617083  23.304787
# 101  Topic 6: USC Organizational Structure\n\nThe U...  22.196563  22.842929
# 44   Topic 7: Admission\n\nThe academic admission r...  18.982541  20.513841
# 19   Topic 8: Admission Steps for Freshmen\n\nThe i...  18.461944  19.255557
# 1    Topic 9: Admission Steps for International Stu...  19.552305  20.424668
# 77   Topic 10: Admission Steps for Transferee\n\nTh...  18.428227  19.075219
#
#         dist_3     dist_4     dist_5     dist_6     dist_7
# 0    22.668039  25.112623  23.288184  22.087395  25.292707
# 1    23.503184  25.036329  23.969033  19.371689  24.768926
# 2     0.000000  24.595079  24.486594  23.543206  23.159292
# 3    24.595079   0.000000  21.257554  24.765791  24.368647
# 4    24.486594  21.257554   0.000000  22.468376  24.194169
# 5    23.543206  24.765791  22.468376   0.000000  24.240844
# 6    23.159292  24.368647  24.194169  24.240844   0.000000
# 95   18.996450  21.098682  21.428712  21.040901  17.542745
# 119  20.450947  23.338648  22.449175  21.999720  18.396513
# 90   21.058618  23.098824  22.249181  22.311607  15.826622
# 15   21.725057  24.623963  22.846074  22.692429  20.272150
# 37   20.441677  23.179803  22.237755  22.239474  20.495382
# 108  19.981606  22.341191  21.523305  21.389468  20.308845
# 83   20.331056  23.358418  22.358773  22.626648  20.002366
# 89   21.904565  24.018569  22.670341  23.159754  22.626089
# 101  18.504748  22.676969  21.512008  21.576035  16.470706
# 44   19.350914  21.751537  20.859729  19.908269  19.896295
# 19   20.074836  22.352300  21.435878  19.772298  20.718508
# 1    20.335630  23.014765  21.770448  20.404397  21.626892
# 77   19.910535  22.527802  21.504956  19.402337  20.675744

# %%
df_cosine.head(20)
# Out:
#                                        id  \
# 0                              question_1
# 1                              question_2
# 2                              question_3
# 3                              question_4
# 4                              question_5
# 5                              question_6
# 6                              question_7
# 95   ae0dbca3-cc02-44e9-b21d-bb4110f0ffb8
# 119  da84031c-f3f3-4e2c-aca9-e9f3068247c7
# 90   a68a39f3-0e0a-44e4-97eb-c2da93483cc8
# 15   18f81ef3-6772-44a3-a32c-7d6874f0f137
# 37   452a0946-0f7a-4cdc-9dae-973aa0c3adec
# 108  c7242ac4-eb9a-4ca9-a553-0be16a1341e7
# 83   9c8ed973-ff53-4a8a-ba6e-6a0657141117
# 89   a673ffee-3754-4395-83b0-fb37ba8b70b8
# 101  b9622134-99f3-4761-b4e7-a246f5094994
# 44   5286140a-903e-4923-839d-846cb3b5065c
# 19   1df03f15-bcd2-4118-9251-26577e15b54e
# 1    04f29dd9-dc6d-4afa-888a-359be093d380
# 77   914de2cf-a197-40dc-8af8-26308dfc8432
#
#                                               question  \
# 0                                       How to enroll?
# 1                    How do I apply for a car sticker?
# 2          Who to contact about student organizations?
# 3      What is the difference between BS CS and BS IT?
# 4    What is the difference between overload, tutor...
# 5    What are the fee discounts available and how c...
# 6               Please discuss the core values of USC.
# 95                                                 NaN
# 119                                                NaN
# 90                                                 NaN
# 15                                                 NaN
# 37                                                 NaN
# 108                                                NaN
# 83                                                 NaN
# 89                                                 NaN
# 101                                                NaN
# 44                                                 NaN
# 19                                                 NaN
# 1                                                  NaN
# 77                                                 NaN
#
#                                              embedding  \
# 0    [-1.4416790008544922, 1.325736403465271, -3.31...
# 1    [-0.09891726821660995, -0.4405957758426666, -3...
# 2    [-1.1395211219787598, -0.04957957565784454, -3...
# 3    [1.1334507465362549, 1.0081663131713867, -2.41...
# 4    [1.0645222663879395, 0.7283675670623779, -3.81...
# 5    [-0.5865501761436462, 0.9015997648239136, -3.5...
# 6    [0.12190892547369003, 0.8585222363471985, -3.4...
# 95   [0.46299073100090027, 0.36808809638023376, -2....
# 119  [-0.01337280310690403, 1.720857858657837, -3.1...
# 90   [0.48381316661834717, 0.8756269812583923, -3.3...
# 15   [-0.26976484060287476, 1.9007909297943115, -3....
# 37   [0.26369062066078186, 1.508581280708313, -3.29...
# 108  [0.10985635221004486, 0.9737294912338257, -2.8...
# 83   [-0.2297847419977188, 1.527048110961914, -3.37...
# 89   [0.21950210630893707, -0.1793101727962494, -4....
# 101  [-0.3399277627468109, 1.633723258972168, -3.11...
# 44   [-0.2553839683532715, 1.5201339721679688, -2.6...
# 19   [-0.6737183332443237, 0.039311494678258896, -2...
# 1    [-0.15944167971611023, 0.8384157419204712, -2....
# 77   [-0.6744738817214966, 0.4461701810359955, -2.9...
#
#                                                 source  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 95                               A00-Abbreviations.txt
# 119                                A01-Description.txt
# 90   A02-Catholic Identity, Vision Mission and Core...
# 15                         A03-The University Seal.txt
# 37                                     A04-History.txt
# 108                                    A04-History.txt
# 83                           A05-University Saints.txt
# 89                           A05-University Saints.txt
# 101               A06-USC Organizational Structure.txt
# 44                                   A07-Admission.txt
# 19                A08-Admission Steps for Freshmen.txt
# 1    A09-Admission Steps for International Students...
# 77              A10-Admission Steps for Transferee.txt
#
#                                               document    dist_1    dist_2  \
# 0                                                  NaN  1.000000  0.543929
# 1                                                  NaN  0.543929  1.000000
# 2                                                  NaN  0.498955  0.430437
# 3                                                  NaN  0.392178  0.362216
# 4                                                  NaN  0.458715  0.392217
# 5                                                  NaN  0.506885  0.597239
# 6                                                  NaN  0.363029  0.353230
# 95   USC stands for University of San Carlos.\nSVD ...  0.457341  0.464826
# 119  TOPIC 1: Description\n\nUniversity of San Carl...  0.459561  0.405676
# 90   TOPIC 2: Catholic Identity, Vision, Mission, a...  0.413277  0.403995
# 15   Topic 3: The University Seal\n\nThe University...  0.435717  0.442853
# 37   Topic 4: History\n\nThe University of San Carl...  0.439082  0.364140
# 108  In 1957, the University became one of the 11 (...  0.462725  0.399860
# 83   Topic 5: University Saints\n\nThe three univer...  0.397482  0.340869
# 89   ST. JOSEPH FREINADEMETZ (1852-1908) \n\nSt. Jo...  0.379909  0.352368
# 101  Topic 6: USC Organizational Structure\n\nThe U...  0.464002  0.390288
# 44   Topic 7: Admission\n\nThe academic admission r...  0.613041  0.510228
# 19   Topic 8: Admission Steps for Freshmen\n\nThe i...  0.638440  0.575031
# 1    Topic 9: Admission Steps for International Stu...  0.589845  0.516840
# 77   Topic 10: Admission Steps for Transferee\n\nTh...  0.640556  0.584213
#
#        dist_3    dist_4    dist_5    dist_6    dist_7
# 0    0.498955  0.392178  0.458715  0.506885  0.363029
# 1    0.430437  0.362216  0.392217  0.597239  0.353230
# 2    1.000000  0.385106  0.366335  0.405335  0.435179
# 3    0.385106  1.000000  0.529170  0.351090  0.383146
# 4    0.366335  0.529170  1.000000  0.443300  0.366920
# 5    0.405335  0.351090  0.443300  1.000000  0.354405
# 6    0.435179  0.383146  0.366920  0.354405  1.000000
# 95   0.551686  0.450260  0.397318  0.406457  0.607627
# 119  0.535396  0.402993  0.422652  0.435849  0.614445
# 90   0.497620  0.403847  0.421039  0.407163  0.710005
# 15   0.482927  0.344741  0.411323  0.409333  0.538502
# 37   0.520582  0.391218  0.413013  0.401936  0.504300
# 108  0.508203  0.390001  0.403231  0.397844  0.473788
# 83   0.518545  0.371583  0.396280  0.369698  0.520439
# 89   0.430203  0.323516  0.368041  0.327100  0.373388
# 101  0.603810  0.409889  0.443126  0.428904  0.677909
# 44   0.565852  0.458070  0.476828  0.514553  0.526813
# 19   0.538043  0.434737  0.455097  0.528121  0.493497
# 1    0.521745  0.394857  0.432521  0.492480  0.442519
# 77   0.546952  0.427333  0.453237  0.547131  0.497120

# %% [markdown]
# ## Store result

# %%
df_euclid.to_csv('embeddings_and_distances(euclid).csv')

# %%
df_cosine.to_csv('embeddings_and_distances(cosine).csv')
