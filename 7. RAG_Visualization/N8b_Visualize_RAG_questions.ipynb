# %%
import pandas as pd
from umap.umap_ import UMAP
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load DataFrame from N7
df_euclid = pd.read_csv('embeddings_and_distances(euclid).csv')
df_cosine = pd.read_csv('embeddings_and_distances(cosine).csv')
df_texts_euclid = df_euclid.copy(deep=True)
df_texts_euclid = df_texts_euclid[df_texts_euclid['question'].isna()]
df_texts_cosine = df_cosine.copy(deep=True)
df_texts_cosine = df_texts_cosine[df_texts_cosine['question'].isna()]

# %%
df_dicts = [{"metric": "Euclidean distance", "df": df_euclid},{"metric": "Cosine Similarity", "df": df_cosine}]

# %%
# Number of dimensions of embedding per document 
# Note that we use UMAP to reduce this to 2 dimensions
len(df_cosine['embedding'][0][1:-1].split(', '))
# Out:
# 768

# %%
# Prepare embeddings
# Prepare the embeddings for UMAP
array = [row for row in df_cosine["embedding"]]
array_float = [[float(x) for x in row[1:-1].split(', ')] for row in array]

# Prepare the embeddings for UMAP
embeddings = np.array(array_float)

# Reduce dimensionality with UMAP
reducer = UMAP(random_state = 2)
embedding_reduced = reducer.fit_transform(embeddings)
# Out:
# C:\Users\Marc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Using UMAP
# Find the 5 closest vectors
for i in range(1,8):
  for dict in df_dicts:

    # Initialize df and top n closest indices
    df = dict['df']

    # Filter metric
    if dict['metric'] == 'Euclidean distance':
      closest_vectors_indices = df_texts_euclid.nsmallest(5, f'dist_{i}')['id'].values
      question_row = df[df[f"dist_{i}"] == df[f"dist_{i}"].min()]
    else:
      closest_vectors_indices = df_texts_cosine.nlargest(5, f'dist_{i}')['id'].values
      question_row = df[df[f"dist_{i}"] == df[f"dist_{i}"].max()]

    # Display question, most similar articles, and score
    print(f"Top 5 most similar articles for question {i}: {question_row['question'].values[0]} (Metric: {dict['metric']})")
    
    top_n_df = df[df["id"].isin(closest_vectors_indices)].sort_values(by=[f'dist_{i}'],ascending = (dict['metric'] == 'Euclidean distance'))
    for idx, row in top_n_df.iterrows():
      print(f"  Score: {row[f'dist_{i}']:.6f} - {row['source']}")
    
    # Plot the reduced embeddings
    plt.scatter(embedding_reduced[:,  0], embedding_reduced[:,  1], c='gray', alpha=0.2)

    # Highlight the question embedding and the  5 closest vectors
    plt.scatter(embedding_reduced[df["id"].isin(closest_vectors_indices),  0], \
                embedding_reduced[df["id"].isin(closest_vectors_indices),  1], c='red', alpha=1, label='Top 5 articles')
    plt.scatter(embedding_reduced[df["id"] == question_row["id"].values[0],  0], \
                embedding_reduced[df["id"] == question_row["id"].values[0],  1], c='blue', alpha=1, marker='*', label='Question')

    # Add labels and title
    plt.title(f"UMAP Visualization of Text Embeddings with Question {i}")
    plt.xlabel(f"Question: {question_row['question'].values[0]}")
    plt.ylabel(f"Metric: {dict['metric']}")
    plt.legend(loc=2)
    plt.show()
# Out:
# Top 5 most similar articles for question 1: How to enroll? (Metric: Euclidean distance)
#   Score: 16.394803 - A18-Enrollment Steps for Continuing Students.txt
#   Score: 16.619028 - A15-Post-Admission Enrollment Steps.txt
#   Score: 16.815499 - A16-Enrollment Mechanics.txt
#   Score: 17.624535 - A24-Simultaneous Enrollment.txt
#   Score: 17.687932 - A28-Additional Enrollment Steps (Shiftee).txt
# Top 5 most similar articles for question 1: How to enroll? (Metric: Cosine Similarity)
#   Score: 0.715796 - A18-Enrollment Steps for Continuing Students.txt
#   Score: 0.703537 - A15-Post-Admission Enrollment Steps.txt
#   Score: 0.699877 - A16-Enrollment Mechanics.txt
#   Score: 0.675922 - A24-Simultaneous Enrollment.txt
#   Score: 0.670164 - A23-Overload.txt
# Top 5 most similar articles for question 2: How do I apply for a car sticker? (Metric: Euclidean distance)
#   Score: 15.515178 - A64-Motor Vehicle Pass Application.txt
#   Score: 17.327996 - A65-Motor Vehicle Rules and Guidelines.txt
#   Score: 19.075219 - A10-Admission Steps for Transferee.txt
#   Score: 19.255557 - A08-Admission Steps for Freshmen.txt
#   Score: 19.367627 - A15-Post-Admission Enrollment Steps.txt
# Top 5 most similar articles for question 2: How do I apply for a car sticker? (Metric: Cosine Similarity)
#   Score: 0.722461 - A64-Motor Vehicle Pass Application.txt
#   Score: 0.652228 - A65-Motor Vehicle Rules and Guidelines.txt
#   Score: 0.584213 - A10-Admission Steps for Transferee.txt
#   Score: 0.575031 - A08-Admission Steps for Freshmen.txt
#   Score: 0.554646 - A32-Transferring out of USC.txt
# Top 5 most similar articles for question 3: Who to contact about student organizations? (Metric: Euclidean distance)
#   Score: 14.898177 - A57-Student Organization Registration and Supervision.txt
#   Score: 16.027143 - A61-Directory of Student Support Services and Programs Part 2.txt
#   Score: 17.254422 - A46-Code of Conduct for Students.txt
#   Score: 17.308749 - A50-Categories and Ranking of Offenses.txt
#   Score: 17.470211 - A60-Directory of Student Support Services and Programs Part 1.txt
# Top 5 most similar articles for question 3: Who to contact about student organizations? (Metric: Cosine Similarity)
#   Score: 0.745265 - A57-Student Organization Registration and Supervision.txt
#   Score: 0.697135 - A61-Directory of Student Support Services and Programs Part 2.txt
#   Score: 0.652701 - A50-Categories and Ranking of Offenses.txt
#   Score: 0.652645 - A46-Code of Conduct for Students.txt
#   Score: 0.641422 - A60-Directory of Student Support Services and Programs Part 1.txt
# Top 5 most similar articles for question 4: What is the difference between BS CS and BS IT? (Metric: Euclidean distance)
#   Score: 16.087851 - B22-BS Computer Science.txt
#   Score: 16.274163 - B30-BS Information Technology.txt
#   Score: 17.168808 - B29-BS Information Systems.txt
#   Score: 18.348719 - B21-BS Computer Engineering.txt
#   Score: 18.746862 - B10-BS Accountancy.txt
# Top 5 most similar articles for question 4: What is the difference between BS CS and BS IT? (Metric: Cosine Similarity)
#   Score: 0.715989 - B22-BS Computer Science.txt
#   Score: 0.709784 - B30-BS Information Technology.txt
#   Score: 0.674373 - B29-BS Information Systems.txt
#   Score: 0.633385 - B21-BS Computer Engineering.txt
#   Score: 0.605478 - B10-BS Accountancy.txt
# Top 5 most similar articles for question 5: What is the difference between overload, tutorial, and override? (Metric: Euclidean distance)
#   Score: 16.726575 - A21-Course Override.txt
#   Score: 16.943559 - A23-Overload.txt
#   Score: 18.602718 - A35-Curricular and Non-Curricular Requirements.txt
#   Score: 18.663061 - A35-Curricular and Non-Curricular Requirements.txt
#   Score: 18.929047 - A25-Tutorial and Petition.txt
# Top 5 most similar articles for question 5: What is the difference between overload, tutorial, and override? (Metric: Cosine Similarity)
#   Score: 0.670538 - A21-Course Override.txt
#   Score: 0.666415 - A23-Overload.txt
#   Score: 0.583205 - A25-Tutorial and Petition.txt
#   Score: 0.574387 - A35-Curricular and Non-Curricular Requirements.txt
#   Score: 0.572250 - A35-Curricular and Non-Curricular Requirements.txt
# Top 5 most similar articles for question 6: What are the fee discounts available and how can I apply for them? (Metric: Euclidean distance)
#   Score: 14.812543 - A31-Fee Discounts.txt
#   Score: 17.681061 - A64-Motor Vehicle Pass Application.txt
#   Score: 17.800404 - A13-College Entrance Examination.txt
#   Score: 18.029131 - A34-Fees and Fees Adjustments.txt
#   Score: 18.345433 - A60-Directory of Student Support Services and Programs Part 1.txt
# Top 5 most similar articles for question 6: What are the fee discounts available and how can I apply for them? (Metric: Cosine Similarity)
#   Score: 0.737625 - A31-Fee Discounts.txt
#   Score: 0.614959 - A64-Motor Vehicle Pass Application.txt
#   Score: 0.611136 - A13-College Entrance Examination.txt
#   Score: 0.600707 - A34-Fees and Fees Adjustments.txt
#   Score: 0.573891 - A25-Tutorial and Petition.txt
# Top 5 most similar articles for question 7: Please discuss the core values of USC. (Metric: Euclidean distance)
#   Score: 15.826622 - A02-Catholic Identity, Vision Mission and Core Values.txt
#   Score: 16.470706 - A06-USC Organizational Structure.txt
#   Score: 17.542745 - A00-Abbreviations.txt
#   Score: 17.837996 - A40-CHL Rationale and Aims.txt
#   Score: 17.920976 - A32-Transferring out of USC.txt
# Top 5 most similar articles for question 7: Please discuss the core values of USC. (Metric: Cosine Similarity)
#   Score: 0.710005 - A02-Catholic Identity, Vision Mission and Core Values.txt
#   Score: 0.677909 - A06-USC Organizational Structure.txt
#   Score: 0.632621 - A40-CHL Rationale and Aims.txt
#   Score: 0.621730 - A32-Transferring out of USC.txt
#   Score: 0.620332 - A46-Code of Conduct for Students.txt
